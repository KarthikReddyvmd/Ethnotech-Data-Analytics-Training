# %% [markdown]
# <a href="https://colab.research.google.com/github/KarthikReddyvmd/Ethnotech-Data-Analytics-Training/blob/main/Day%204/Module1Assignments/Analysis-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import statistics

Order_time=[6,8,12,1,6,2,9,10,2,5]
Delivery_time=[30,20,39,45,60,40,35,55,65,40]
Delivery_partner=[1,3,2,1,2,3,1,1,2,3]
Customer_ratings=[5,4,5,2,2,3,5,4,5,3]

df=pd.DataFrame({'Order_time':Order_time,'Delivery_time':Delivery_time,'Delivery_partner':Delivery_partner,'Customer_ratings':Customer_ratings})
df
# Out:
#    Order_time  Delivery_time  Delivery_partner  Customer_ratings
# 0           6             30                 1                 5
# 1           8             20                 3                 4
# 2          12             39                 2                 5
# 3           1             45                 1                 2
# 4           6             60                 2                 2
# 5           2             40                 3                 3
# 6           9             35                 1                 5
# 7          10             55                 1                 4
# 8           2             65                 2                 5
# 9           5             40                 3                 3

# %%
print('--------------Average Delivary Time-------------------')
print('\n',df.groupby('Delivery_partner')['Delivery_time'].mean())
# Out:
# --------------Average Delivary Time-------------------
#
#  Delivery_partner
# 1    41.250000
# 2    54.666667
# 3    33.333333
# Name: Delivery_time, dtype: float64

# %%
print('---------------Peak Order Hours-------------------')

order_counts = df['Order_time'].value_counts().sort_index()

print('\nMaximum Order Time:', df['Order_time'].max())

plt.figure(figsize=(10, 6))
plt.stem(order_counts.index, order_counts.values)
plt.title('Frequency of Orders by Hour')
plt.xlabel('Order Hour')
plt.ylabel('Number of Orders')
plt.xticks(order_counts.index)
plt.grid(axis='y', linestyle='--')
plt.show()
# Out:
# ---------------Peak Order Hours-------------------
#
# Maximum Order Time: 12

# %%
import matplotlib.pyplot as plt

print('---------------Most Delayed Areas--------------')
max_delays = df.groupby('Delivery_partner')['Delivery_time'].max()
print('\n', max_delays)

plt.figure(figsize=(10, 6))
plt.bar(max_delays.index, max_delays.values,color='skyblue')
plt.title('Maximum Delivery Time by Partner')
plt.xlabel('Delivery Partner')
plt.ylabel('Max Delivery Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------Most Delayed Areas--------------
#
#  Delivery_partner
# 1    55
# 2    65
# 3    40
# Name: Delivery_time, dtype: int64

# %%
import matplotlib.pyplot as plt

print('---------------Top rated Delivery partners-------------------')
avg_ratings = df.groupby('Delivery_partner')['Customer_ratings'].mean()
print('\n', avg_ratings)

plt.figure(figsize=(10,5))
plt.bar(avg_ratings.index, avg_ratings.values, color='skyblue')
plt.title('Average Customer Ratings by Delivery Partner')
plt.xlabel('Delivery Partner')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------Top rated Delivery partners-------------------
#
#  Delivery_partner
# 1    4.000000
# 2    4.000000
# 3    3.333333
# Name: Customer_ratings, dtype: float64
