# %% [markdown]
# <a href="https://colab.research.google.com/github/KarthikReddyvmd/Ethnotech-Data-Analytics-Training/blob/main/Day%2021/%20missingvalues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.colab

# %% [markdown]
# To upload files from your local system to Colab, you can use `google.colab.files.upload()`. This will open a file selection dialog in your browser.

# %%
from google.colab import files

# This will open a file selection dialog. Choose the files you want to upload.
uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-6dc78237-9f76-4bb2-aeac-c22ec1046f98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6dc78237-9f76-4bb2-aeac-c22ec1046f98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('weather.csv')
print (df.head())
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
print('Number of missing values per column:')
display(df.isnull().sum())
# Out:
# Number of missing values per column:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
print(df.mean(numeric_only=True))
# Out:
# MinTemp             7.265574
# MaxTemp            20.550273
# Rainfall            1.428415
# Evaporation         4.521858
# Sunshine            7.909366
# WindGustSpeed      39.840659
# WindSpeed9am        9.651811
# WindSpeed3pm       17.986339
# Humidity9am        72.035519
# Humidity3pm        44.519126
# Pressure9am      1019.709016
# Pressure3pm      1016.810383
# Cloud9am            3.890710
# Cloud3pm            4.024590
# Temp9am            12.358470
# Temp3pm            19.230874
# RISK_MM             1.428415
# dtype: float64

# %%
print(df.median(numeric_only=True))
# Out:
# MinTemp             7.45
# MaxTemp            19.65
# Rainfall            0.00
# Evaporation         4.20
# Sunshine            8.60
# WindGustSpeed      39.00
# WindSpeed9am        7.00
# WindSpeed3pm       17.00
# Humidity9am        72.00
# Humidity3pm        43.00
# Pressure9am      1020.15
# Pressure3pm      1017.40
# Cloud9am            3.50
# Cloud3pm            4.00
# Temp9am            12.55
# Temp3pm            18.55
# RISK_MM             0.00
# dtype: float64

# %%
# Drop rows with any missing values
df_cleaned = df.dropna()

print(f"Shape of DataFrame after dropping missing values: {df_cleaned.shape}")
display(df_cleaned.head())
# Out:
# Shape of DataFrame after dropping missing values: (328, 22)
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
print('Number of missing values per column:')
display(df_cleaned.isnull().sum())
# Out:
# Number of missing values per column:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
display(df_cleaned.mean(numeric_only=True))
# Out:
# MinTemp             7.742988
# MaxTemp            20.897561
# Rainfall            1.440854
# Evaporation         4.702439
# Sunshine            8.014939
# WindGustSpeed      40.396341
# WindSpeed9am       10.414634
# WindSpeed3pm       18.185976
# Humidity9am        71.100610
# Humidity3pm        44.003049
# Pressure9am      1019.350000
# Pressure3pm      1016.530793
# Cloud9am            3.905488
# Cloud3pm            4.000000
# Temp9am            12.815549
# Temp3pm            19.556402
# RISK_MM             1.422561
# dtype: float64

# %%
display(df_cleaned.median(numeric_only=True))
# Out:
# MinTemp             7.90
# MaxTemp            20.40
# Rainfall            0.00
# Evaporation         4.40
# Sunshine            8.75
# WindGustSpeed      39.00
# WindSpeed9am        7.00
# WindSpeed3pm       17.00
# Humidity9am        71.00
# Humidity3pm        42.50
# Pressure9am      1019.75
# Pressure3pm      1016.90
# Cloud9am            4.00
# Cloud3pm            4.00
# Temp9am            13.50
# Temp3pm            18.85
# RISK_MM             0.00
# dtype: float64
