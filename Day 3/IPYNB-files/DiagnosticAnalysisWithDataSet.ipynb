# %% [markdown]
# <a href="https://colab.research.google.com/github/KarthikReddyvmd/Ethnotech-Data-Analytics-Training/blob/main/Day%203/IPYNB-files/DiagnosticAnalysisWithDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ff61f428-533f-489e-8648-61fecd130a5e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff61f428-533f-489e-8648-61fecd130a5e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

df=pd.read_csv("churn-bigml-20.csv")
print(df.head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
plt.figure(figsize=(20,10))
sb.countplot(x=df['State'], hue=df['Churn'])
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.title('Churn by State')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sb.scatterplot(x=df['Total day calls'], y=df['Total day charge'], hue=df['State'], data=df, s=50)
plt.xlabel('Total day calls')
plt.ylabel('Total day charge')
plt.title('Total day calls vs Total day charge by State')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,5))
sb.scatterplot(x=df['Total night calls'], y=df['Total night charge'], hue=df['State'], data=df, s=50)
plt.xlabel('Total night calls')
plt.ylabel('Total night charge')
plt.title('Total night calls vs Total night charge by State')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.tight_layout()
plt.show()
